# %%
t=(1,2,3)
for i in t: print(i)
# Out:
# 1
# 2
# 3

# %%
t=(1,2,2,3)
print(t.count(2))
for i in t: print(i)
# Out:
# 2
# 1
# 2
# 2
# 3

# %%
t=(10,20,30)
print(t.index(20))
for i in t: print(i)
# Out:
# 1
# 10
# 20
# 30

# %%
t1=(1,2); t2=(3,4)
t=t1+t2
for i in t: print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
t=(5,6)
t=t*2
for i in t: print(i)
# Out:
# 5
# 6
# 5
# 6

# %%
t=(10,20,30)
a,b,c=t
for i in t: print(i)
# Out:
# 10
# 20
# 30

# %%
t=(10,20,30)
a,b,c=t
for i in t: print(i)
# Out:
# 10
# 20
# 30

# %%
t=((1,2),(3,4))
for i in t: print(i)
# Out:
# (1, 2)
# (3, 4)

# %%
t=(1,2,3)
print(len(t))
for i in t: print(i)
# Out:
# 3
# 1
# 2
# 3

# %%
t=(1,2,3,4)
for i in t[1:3]: print(i)
# Out:
# 2
# 3
