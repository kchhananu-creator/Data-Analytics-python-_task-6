# %%
d1 = {
    "name": "Saloni",
    "age": 23,
    "class": "Data_Analytics",
    "batch": "da25"
}

print (d1)
# Out:
# {'name': 'Saloni', 'age': 23, 'class': 'Data_Analytics', 'batch': 'da25'}

# %%
d={"name":"Rahul"}
d["age"]=20
for k in d: print(k,d[k])
# Out:
# name Rahul
# age 20

# %%
d={"x":1}
d.clear()
print(d)
# Out:
# {}

# %%
d={"a":1}
d.update({"b":2})
for k,v in d.items(): print(k,v)
# Out:
# a 1
# b 2

# %%
d={"a":1}
print("a" in d)
for i in d: print(i,d[i])
# Out:
# True
# a 1

# %%
d={"p":100,"q":200}
for i in d.keys(): print(i)
# Out:
# p
# q

# %%
d={"a":1,"b":2}
d.pop("a")
for i in d: print(i,d[i])
# Out:
# b 2

# %%
d={"a":1,"b":2}
for k,v in d.items(): print(k,v)
# Out:
# a 1
# b 2

# %%
d={"s1":{"name":"A"}}
for k,v in d.items(): print(k,v)
# Out:
# s1 {'name': 'A'}

# %%
d={"p":100,"q":200}
for i in d.values(): print(i)
# Out:
# 100
# 200
