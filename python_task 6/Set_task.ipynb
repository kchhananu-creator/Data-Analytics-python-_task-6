# %%
s = {1, 2, 3, 4}
s.add(5)

for i in s:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
s = {"a","b","c"}
s.remove("b")
for i in s: print(i)
# Out:
# a
# c

# %%
set = {20,30}
s.update([30,40])
for i in s: print(i)
# Out:
# 40
# a
# c
# 30

# %%
a = {1,2}; b = {2,3}
c=a.union(b)
for i in c:print(i)
# Out:
# 1
# 2
# 3

# %%
a = {1,2,3}; b = {2,3}
c=a.intersection(b)
for i in c:print(i)
# Out:
# 2
# 3

# %%
s={1,2,3}
s.pop()
for i in s: print(i)
# Out:
# 2
# 3

# %%
a={1,2}; b={2,3}
c=a.symmetric_difference(b)
for i in c: print(i)
# Out:
# 1
# 3

# %%
s={100,200}
print(200 in s)
for i in s: print(i)
# Out:
# True
# 200
# 100

# %%
a={1,2,3}; b={2}
c=a.difference(b)
for i in c: print(i)
# Out:
# 1
# 3

# %%
s={5,6,7}
s.discard(6)
for i in s: print(i)
# Out:
# 5
# 7
